# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#iris_filepath = "G:\My Drive\03.Kaggle\04.Data_Visulization\iris.csv"
iris_data = pd.read_csv(r'G:\My Drive\03.Kaggle\04.Data_Visulization\iris.csv')

# %%
iris_data.head()
# Out:
#    Id  Sepal Length (cm)  Sepal Width (cm)  Petal Length (cm)  \
# 0   1                5.1               3.5                1.4
# 1   2                4.9               3.0                1.4
# 2   3                4.7               3.2                1.3
# 3   4                4.6               3.1                1.5
# 4   5                5.0               3.6                1.4
#
#    Petal Width (cm)      Species
# 0               0.2  Iris-setosa
# 1               0.2  Iris-setosa
# 2               0.2  Iris-setosa
# 3               0.2  Iris-setosa
# 4               0.2  Iris-setosa

# %%
sns.histplot(data=iris_data['Petal Length (cm)'])
# Out:
# <Axes: xlabel='Petal Length (cm)', ylabel='Count'>

# %%
sns.kdeplot(iris_data['Petal Width (cm)'])
# Out:
# <Axes: xlabel='Petal Width (cm)', ylabel='Density'>

# %%
sns.jointplot(x=iris_data['Petal Length (cm)'], y = iris_data['Petal Width (cm)'],kind = 'kde')

# %%
sns.jointplot(x=iris_data['Petal Length (cm)'], y = iris_data['Petal Width (cm)'],kind = 'scatter')

# %%
sns.jointplot(x=iris_data['Petal Length (cm)'], y = iris_data['Petal Width (cm)'],kind = 'hex')

# %%
sns.jointplot(x=iris_data['Petal Length (cm)'], y = iris_data['Petal Width (cm)'],kind = 'reg')

# %%
sns.histplot(data=iris_data, x='Petal Length (cm)', hue='Species')
# Out:
# <Axes: xlabel='Petal Length (cm)', ylabel='Count'>

# %%
sns.kdeplot(data=iris_data, x='Petal Length (cm)', hue='Species', shade=True)
# Out:
# C:\Users\PC\AppData\Local\Temp\ipykernel_3044\2931602481.py:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data=iris_data, x='Petal Length (cm)', hue='Species', shade=True)
# <Axes: xlabel='Petal Length (cm)', ylabel='Density'>

# %%
sns.kdeplot(data=iris_data, x='Petal Length (cm)', hue='Species', shade=False)
# Out:
# C:\Users\PC\AppData\Local\Temp\ipykernel_3044\4110707353.py:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=False`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data=iris_data, x='Petal Length (cm)', hue='Species', shade=False)
# <Axes: xlabel='Petal Length (cm)', ylabel='Density'>

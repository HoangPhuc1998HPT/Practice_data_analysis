# %%
import pandas as pd
pd.plotting.register_matplotlib_converters()
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
cancer_data = pd.read_csv(r'G:\My Drive\03.Kaggle\04.Data_Visulization\cancer.csv', index_col="Id")

# %%
cancer_data.head()
# Out:
#          Diagnosis  Radius (mean)  Texture (mean)  Perimeter (mean)  \
# Id
# 8510426          B         13.540           14.36             87.46
# 8510653          B         13.080           15.71             85.63
# 8510824          B          9.504           12.44             60.34
# 854941           B         13.030           18.42             82.61
# 85713702         B          8.196           16.84             51.71
#
#           Area (mean)  Smoothness (mean)  Compactness (mean)  \
# Id
# 8510426         566.3            0.09779             0.08129
# 8510653         520.0            0.10750             0.12700
# 8510824         273.9            0.10240             0.06492
# 854941          523.8            0.08983             0.03766
# 85713702        201.9            0.08600             0.05943
#
#           Concavity (mean)  Concave points (mean)  Symmetry (mean)  ...  \
# Id                                                                  ...
# ...

# %%
cancer_data.tail()
# Out:
#        Diagnosis  Radius (mean)  Texture (mean)  Perimeter (mean)  \
# Id
# 926125         M          20.92           25.09             143.0
# 926424         M          21.56           22.39             142.0
# 926682         M          20.13           28.25             131.2
# 926954         M          16.60           28.08             108.3
# 927241         M          20.60           29.33             140.1
#
#         Area (mean)  Smoothness (mean)  Compactness (mean)  Concavity (mean)  \
# Id
# 926125       1347.0            0.10990              0.2236           0.31740
# 926424       1479.0            0.11100              0.1159           0.24390
# 926682       1261.0            0.09780              0.1034           0.14400
# 926954        858.1            0.08455              0.1023           0.09251
# 927241       1265.0            0.11780              0.2770           0.35140
#
#         Concave points (mean)  Symmetry (mean)  ...  Radius (worst)  \
# ...

# %%
sns.lineplot(data = cancer_data, x ='Radius (mean)', y = 'Perimeter (mean)', hue = 'Diagnosis')
sns.set_style("whitegrid")
